# %%
import pandas as pd
from dask import dataframe as dd
from faker import Faker
import numpy as np
# Out:
# /opt/homebrew/lib/python3.9/site-packages/dask/dataframe/__init__.py:42: FutureWarning:
# Dask dataframe query planning is disabled because dask-expr is not installed.
#
# You can install it with `pip install dask[dataframe]` or `conda install dask`.
# This will raise in a future version.
#
#   warnings.warn(msg, FutureWarning)

# %%
data = 'Data/FactInternetSales.csv'

df = pd.read_csv(data)

# Convert all column names to lowercase incase
df.columns = [col.lower() for col in df.columns]

# %%
df.head(10)
# Out:
#    productkey  orderdatekey  duedatekey  shipdatekey  customerkey  \
# 0         310      20101229    20110110     20110105        21768
# 1         346      20101229    20110110     20110105        28389
# 2         346      20101229    20110110     20110105        25863
# 3         336      20101229    20110110     20110105        14501
# 4         346      20101229    20110110     20110105        11003
# 5         311      20101230    20110111     20110106        27645
# 6         310      20101230    20110111     20110106        16624
# 7         351      20101230    20110111     20110106        11005
# 8         344      20101230    20110111     20110106        11011
# 9         312      20101231    20110112     20110107        27621
#
#    promotionkey  currencykey  salesterritorykey salesordernumber  \
# 0             1           19                  6          SO43697
# 1             1           39                  7          SO43698
# ...

# %%
df_dask = dd.read_csv(data)
df_dask.columns = [col.lower() for col in df_dask.columns]
df_dask.head(10)
# Out:
#    productkey  orderdatekey  duedatekey  shipdatekey  customerkey  \
# 0         310      20101229    20110110     20110105        21768
# 1         346      20101229    20110110     20110105        28389
# 2         346      20101229    20110110     20110105        25863
# 3         336      20101229    20110110     20110105        14501
# 4         346      20101229    20110110     20110105        11003
# 5         311      20101230    20110111     20110106        27645
# 6         310      20101230    20110111     20110106        16624
# 7         351      20101230    20110111     20110106        11005
# 8         344      20101230    20110111     20110106        11011
# 9         312      20101231    20110112     20110107        27621
#
#    promotionkey  currencykey  salesterritorykey salesordernumber  \
# 0             1           19                  6          SO43697
# 1             1           39                  7          SO43698
# ...

# %%
df_dask = dd.from_pandas(df, npartitions=4)
df_dask.head(10)
# Out:
#    productkey  orderdatekey  duedatekey  shipdatekey  customerkey  \
# 0         310      20101229    20110110     20110105        21768
# 1         346      20101229    20110110     20110105        28389
# 2         346      20101229    20110110     20110105        25863
# 3         336      20101229    20110110     20110105        14501
# 4         346      20101229    20110110     20110105        11003
# 5         311      20101230    20110111     20110106        27645
# 6         310      20101230    20110111     20110106        16624
# 7         351      20101230    20110111     20110106        11005
# 8         344      20101230    20110111     20110106        11011
# 9         312      20101231    20110112     20110107        27621
#
#    promotionkey  currencykey  salesterritorykey salesordernumber  \
# 0             1           19                  6          SO43697
# 1             1           39                  7          SO43698
# ...

# %%
pip install dask
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.2 MB/s  0:00:00 eta 0:00:01
# ...
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
